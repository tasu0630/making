# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import joblib

# %%
# 学習データの読み込み
train_df=pd.read_csv("/Users/tasuke0630/making/DataScience/kaggle/Taitanic/train.csv")

# テストデータの読み込み
test_df=pd.read_csv("/Users/tasuke0630/making/DataScience/kaggle/Taitanic/test.csv")

# 学習データとテストデータを連結する
df=pd.concat([train_df,test_df],ignore_index=True)
#nullのCSV化
df_null=df.isnull().sum()
df_null.to_csv("null.csv")

# 元データをコピー
df2=df.copy()

# %%
#null_csvを見ながら,nullのデータの確認
#sns.countplot("Survived",data=df2)
#sns.countplot("Age",data=df2)
#sns.countplot("Fare",data=df2)
#sns.countplot("Cabin",data=df2)
#sns.countplot("Embarked",data=df2)

# %%
print(df2.Cabin.mode())
print(df2.Fare.mode())

Age_mdeian=df2.Age.median()
df2.Age=df2.Age.fillna(Age_mdeian)
# Out:
# 0    C23 C25 C27
# dtype: object
# 0    8.05
# dtype: float64

# %%
# 欠損値の補完
df2.Fare=df2.Fare.fillna(8.05)
df2.Cabin=df2.Cabin.fillna("C23")
df2.Embarked=df2.Embarked.fillna("S")

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# dtype: int64

# %%
#使わないカラムを削除する
df3=df2.drop(columns=["Name","Ticket"])
df3.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.503186     0.498854
# std     378.020061    0.486592     0.837836    12.905241     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    22.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    35.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.276193
# std       0.865560    51.743584
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
#カテゴリカル変数の数値変換
tmp_Sex=pd.get_dummies(df3["Sex"],prefix="Sex")
df3=pd.concat([df3,tmp_Sex],axis=1).drop(columns="Sex")

tmp_Cabin=pd.get_dummies(df3["Cabin"],prefix="Cabin")
df3=pd.concat([df3,tmp_Cabin],axis=1).drop(columns="Cabin")

tmp_Embarked=pd.get_dummies(df3["Embarked"],prefix="Embarked")
df3=pd.concat([df3,tmp_Embarked],axis=1).drop(columns="Embarked")
df3.sample(10)
# Out:
#       PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  Sex_female  \
# 497           498       0.0       3  28.0      0      0   15.1000           0
# 633           634       0.0       1  28.0      0      0    0.0000           0
# 517           518       0.0       3  28.0      0      0   24.1500           0
# 441           442       0.0       3  20.0      0      0    9.5000           0
# 965           966       NaN       1  35.0      0      0  211.5000           1
# 168           169       0.0       1  28.0      0      0   25.9250           0
# 884           885       0.0       3  25.0      0      0    7.0500           0
# 412           413       1.0       1  33.0      1      0   90.0000           1
# 1187         1188       NaN       2   1.0      1      2   41.5792           1
# 1288         1289       NaN       1  48.0      1      1   79.2000           1
#
#       Sex_male  Cabin_A10  ...  Cabin_F G73  Cabin_F2  Cabin_F33  Cabin_F38  \
# 497          1          0  ...            0         0          0          0
# 633          1          0  ...            0         0          0          0
# 517          1          0  ...            0         0          0          0
# 441          1          0  ...            0         0          0          0
# 965          0          0  ...            0         0          0          0
# 168          1          0  ...            0         0          0          0
# 884          1          0  ...            0         0          0          0
# 412          0          0  ...            0         0          0          0
# 1187         0          0  ...            0         0          0          0
# 1288         0          0  ...            0         0          0          0
#
#       Cabin_F4  Cabin_G6  Cabin_T  Embarked_C  Embarked_Q  Embarked_S
# 497          0         0        0           0           0           1
# 633          0         0        0           0           0           1
# 517          0         0        0           0           1           0
# 441          0         0        0           0           0           1
# 965          0         0        0           1           0           0
# 168          0         0        0           0           0           1
# 884          0         0        0           0           0           1
# 412          0         0        0           0           1           0
# 1187         0         0        0           1           0           0
# 1288         0         0        0           1           0           0
#
# [10 rows x 199 columns]

# %%
# 学習データに分割した結果を変数trainに格納する
train=df3[~df3.Survived.isnull()]

# テストデータに分割した結果を変数trainに格納する
test=df3[df3.Survived.isnull()]

#trainのデータ
train_x=train.drop(columns=["Survived","PassengerId"])
train_y=train["Survived"]

# %%
clf=RandomForestClassifier(random_state=0,
                                       n_estimators=300,
                                       criterion="gini",
                                       max_depth=6,
                                       oob_score=True,
                                       warm_start=False,
                                      class_weight=None)

# %%
clf.fit(train_x,train_y)

y_pred_train=clf.predict(train_x)
print(classification_report(train_y,y_pred_train))

# 学習結果の検証
X_test=test.drop(columns=["Survived","PassengerId"])
y_predict=clf.predict(X_test)

print("Model score: %.3f"% clf.score(X_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.95      0.88       549
#          1.0       0.89      0.69      0.77       342
#
#     accuracy                           0.85       891
#    macro avg       0.86      0.82      0.83       891
# weighted avg       0.85      0.85      0.84       891
#
# Model score: 1.000

# %%
#type(y_predict)
result=pd.DataFrame(y_predict)

#列名に名前をつける
result2=result.rename(columns={result.columns[0]: "Survived"})

#PassngerIdを合わせる
l=[]
l2=[]
t_id=test_df.loc[:,"PassengerId"]
for i in range(len(t_id)):
               tmp={
                   "PassengerId":t_id[i]
               }
               l.append(tmp);
               
l2=pd.DataFrame(l);
result3=pd.concat([l2,result2],axis=1)


#予測結果を整数に変換する
result3.Survived=result3.Survived.astype(int)
result3.PassengerId=result3.PassengerId.astype(int)

# %%
# CSVの作成
result3.to_csv("predict5.csv",index=False)
